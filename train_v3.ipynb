# %%
from tqdm import tqdm
from models import CompletionNetwork, ContextDiscriminator, GlobalDiscriminator_P
from datasets3 import ImageDataset
from losses import completion_network_loss, completion_network_loss_P
from noise import AddGaussianNoise
from utils import (
    gen_input_mask,
    gen_hole_area,
    crop,
    sample_random_batch,
    poisson_blend,
)
from torch.utils.data import DataLoader
from torch.optim import Adadelta, Adam
from torch.nn import BCELoss, DataParallel
from torchvision.utils import save_image
import torchvision.utils as vutils
from PIL import Image
import torchvision.transforms as transforms
import torch
import random
import os
import argparse
import numpy as np
import json
import time

import cv2
import matplotlib.pyplot as plt
import glob

# %%
# !pwd
# Out:
# /root/notebooks/Module_final/pedestrian_generator

# %%
data_path = "/root/notebooks/Module_final/gandatamask2v1"
out_path = "/root/notebooks/Module_final/result"

# %%
sorted(glob.glob(data_path+'/people/*'), key=lambda x: x[-10:-3])[:10]
# Out:
# ['/root/notebooks/Module_final/gandatamask2v1/people/000000.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000001.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000002.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000003.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000004.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000005.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000006.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000007.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000008.jpg',
#  '/root/notebooks/Module_final/gandatamask2v1/people/000009.jpg']

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--data_dir', type=str, default=data_path)
parser.add_argument('--result_dir', type=str, default=out_path)
parser.add_argument('--recursive_search', action='store_true', default=False)
parser.add_argument('--init_model_cn', type=str, default=None)
parser.add_argument('--init_model_cd', type=str, default=None)
parser.add_argument('--steps_1', type=int, default=3000)
parser.add_argument('--steps_2', type=int, default=2000)
parser.add_argument('--steps_3', type=int, default=1000)
parser.add_argument('--snaperiod_1', type=int, default=400)
parser.add_argument('--snaperiod_2', type=int, default=100)
parser.add_argument('--snaperiod_3', type=int, default=400)
parser.add_argument('--max_holes', type=int, default=1)
parser.add_argument('--hole_min_w', type=int, default=48)
parser.add_argument('--hole_max_w', type=int, default=96)
parser.add_argument('--hole_min_h', type=int, default=48)
parser.add_argument('--hole_max_h', type=int, default=96)
parser.add_argument('--cn_input_size', type=int, default=256)
parser.add_argument('--ld_input_size', type=int, default=256)
parser.add_argument('--optimizer', type=str, choices=['adadelta', 'adam'], default='adam')
parser.add_argument('--bsize', type=int, default=16)
parser.add_argument('--bdivs', type=int, default=1)
parser.add_argument('--data_parallel', action='store_true')
parser.add_argument('--num_test_completions', type=int, default=3)
parser.add_argument('--mpv', nargs=3, type=float, default=None)
parser.add_argument('--alpha', type=float, default=4e-3)
parser.add_argument('--arc', type=str, choices=['celeba', 'places2'], default='celeba')

parser.add_argument('-f')
# Out:
# _StoreAction(option_strings=['-f'], dest='f', nargs=None, const=None, default=None, type=None, choices=None, help=None, metavar=None)

# %%
args = parser.parse_args()

# %%
# ================================================
# Preparation
# ================================================
args.data_dir = os.path.expanduser(args.data_dir)
args.result_dir = os.path.expanduser(args.result_dir)
if args.init_model_cn != None:
    args.init_model_cn = os.path.expanduser(args.init_model_cn)
if args.init_model_cd != None:
    args.init_model_cd = os.path.expanduser(args.init_model_cd)
if torch.cuda.is_available() == False:
    raise Exception('At least one gpu must be available.')
else:
    gpu = torch.device('cuda:0')

# create result directory (if necessary)
if os.path.exists(args.result_dir) == False:
    os.makedirs(args.result_dir)

    
#code below not used    
for s in ['phase_1', 'phase_2', 'phase_3']:
    if os.path.exists(os.path.join(args.result_dir, s)) == False:
        os.makedirs(os.path.join(args.result_dir, s))

# %%
# dataset
trnsfm = transforms.Compose([
    transforms.ToTensor(),
    AddGaussianNoise(0., 1.)
])

test_dset = ImageDataset(args.data_dir)
dataloader = DataLoader(test_dset, batch_size=64, shuffle=False)

# %%
len(test_dset)
# Out:
# 5479

# %%
timg = cv2.cvtColor(np.asarray(test_dset.__getitem__(1000)[0]),cv2.COLOR_RGB2BGR)
print("Image size ",timg.shape)
# Out:
# Image size  (256, 256, 3)

# %%
imgs = []
for i in range(3):
    imgs.append(cv2.cvtColor(np.asarray(test_dset.__getitem__(i+100)[0]),cv2.COLOR_RGB2BGR))
    imgs.append(cv2.cvtColor(np.asarray(test_dset.__getitem__(i+100)[1]),cv2.COLOR_RGB2BGR))
    imgs.append(cv2.cvtColor(np.asarray(test_dset.__getitem__(i+100)[2]),cv2.COLOR_RGB2BGR))

#imgs = np.array([cv2.cvtColor(np.asarray(test_dset.__getitem__(i)[0]),cv2.COLOR_RGB2BGR) for i in range(64)])

# %%
np.array(imgs)[:,[2, 0, 1]].shape
# Out:
# (9, 3, 256, 3)

# %%
imgs = np.einsum('klij->kjli', np.array(imgs))
print(imgs.shape)
# Out:
# (9, 3, 256, 256)

# %%
real_batch = torch.from_numpy(imgs)
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[:9][:,[2,1,0],:,:], padding=2, nrow=3).cpu(),(1,2,0)))

# %%
# dataset

trnsfm = transforms.Compose([
    transforms.ToTensor(),
    
])

trnsfm2 = transforms.Compose([
    transforms.ToTensor(),
    AddGaussianNoise(0., 0.001)
])
print('loading dataset... (it may take a few minutes)')
train_dset = ImageDataset(args.data_dir, trnsfm,trnsfm2, load2meme = True)
test_dset = ImageDataset(args.data_dir, trnsfm,trnsfm2, load2meme = False)
train_loader = DataLoader(train_dset, batch_size=(args.bsize // args.bdivs), shuffle=True)


alpha = torch.tensor(args.alpha).to(gpu)
# Out:
# loading dataset... (it may take a few minutes)
# 100%|██████████| 5479/5479 [02:14<00:00, 40.67it/s]

# %%
# print(train_dset.__getitem__(0)[0].size())
# print(type(train_dset.__getitem__(0)[0]))
# print(train_dset.__getitem__(0)[1].size())
# print(train_dset.__getitem__(0)[2])

# %%
print(iter(train_loader).next()[0].size())
print(iter(train_loader).next()[1].size())
print(iter(train_loader).next()[2].size())
print(torch.cat((iter(train_loader).next()[0], iter(train_loader).next()[1]), dim=1).size())
# Out:
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 3, 256, 256])
# torch.Size([16, 6, 256, 256])

# %%
# Create model G

model_cn = CompletionNetwork()
if args.data_parallel:
    model_cn = DataParallel(model_cn)
if args.init_model_cn != None:
    model_cn.load_state_dict(torch.load(args.init_model_cn, map_location='cpu'))
if args.optimizer == 'adadelta':
    opt_cn = Adadelta(model_cn.parameters(), lr=0.8)
else:
    opt_cn = Adam(model_cn.parameters())
model_cn = model_cn.to(gpu)

# Create model D
model_cd = GlobalDiscriminator_P((3, args.ld_input_size, args.ld_input_size))

if args.data_parallel:
    model_cd = DataParallel(model_cd)
if args.init_model_cd != None:
    model_cd.load_state_dict(torch.load(args.init_model_cd, map_location='cpu'))
if args.optimizer == 'adadelta':
    opt_cd = Adadelta(model_cd.parameters(), lr=0.8)
else:
    opt_cd = Adam(model_cd.parameters())
model_cd = model_cd.to(gpu)
bceloss = BCELoss()

# %%
def train_G(n,steps):
    cnt_bdivs = 0
    pbar = tqdm(total=steps)
    while pbar.n < steps:
        for street_img, mask_poeple, mask, left_top in train_loader:
            street_img = street_img.to(gpu)
            mask_poeple = mask_poeple.to(gpu)
            mask = mask.to(gpu)

            input = torch.cat((street_img, mask_poeple), dim=1)
            output = model_cn(input)
            #loss = completion_network_loss(x, output, mask)
            #loss = torch.nn.functional.mse_loss(output, street_img)
            
            loss = completion_network_loss_P(street_img, mask_poeple, mask, output, left_top, height = 128 , width = 64)

            # backward
            loss.backward()
            cnt_bdivs += 1

            if cnt_bdivs >= args.bdivs:
                cnt_bdivs = 0
                # optimize
                opt_cn.step()
                # clear grads
                opt_cn.zero_grad()
                # update progbar
                pbar.set_description('%d | phase 1 | train loss: %.5f' % (n,loss.cpu()))
                pbar.update()
                if pbar.n % args.snaperiod_1 == 0:
                    with torch.no_grad():
                        x1, x2, x3 = sample_random_batch(test_dset, batch_size=3)
                        x1 = x1.to(gpu)
                        x2 = x2.to(gpu)
                        x3 = (x3).le(0.5).to(torch.uint8) * 255

                        input = torch.cat((x1, x2), dim=1)
                        output = model_cn(input)
                        completed = poisson_blend(output, x1, x3)
                        imgs = torch.cat((x1.cpu(), x2.cpu(), output.cpu(),completed.cpu()), dim=2)
                        imgpath = os.path.join(args.result_dir, 'phase_1', '%d_step%d.png' % (n , pbar.n))
                        model_cn_path = os.path.join(args.result_dir, 'phase_1', '%d_model_cn_step%d' % (n , pbar.n))
                        save_image(imgs, imgpath, nrow=len(x1))
                        if args.data_parallel:
                            torch.save(model_cn.module.state_dict(), model_cn_path)
                        else:
                            torch.save(model_cn.state_dict(), model_cn_path)
                # terminate
                if pbar.n >= steps:
                    break
    pbar.close()

# %%
# train_G(1,1)

# %%
def train_D(n,steps):
    cnt_bdivs = 0
    pbar = tqdm(total=steps)
    while pbar.n < steps:
        for street_img, mask_poeple, _, _ in train_loader:

            # fake forward
            street_img = street_img.to(gpu)
            mask_poeple = mask_poeple.to(gpu)

            fake = torch.zeros((len(street_img), 1)).to(gpu)

            input_cn = torch.cat((street_img, mask_poeple), dim=1)
            output_cn = model_cn(input_cn)

            input_gd_fake = output_cn.detach()
            output_fake = model_cd(input_gd_fake.to(gpu))
            loss_fake = bceloss(output_fake, fake)

            # real forward
            real = torch.ones((len(street_img), 1)).to(gpu)
            input_gd_real = street_img
            output_real = model_cd(input_gd_real.to(gpu))
            loss_real = bceloss(output_real, real)

            # reduce
            loss = (loss_fake + loss_real) / 2.

            # backward
            loss.backward()
            cnt_bdivs += 1

            if cnt_bdivs >= args.bdivs:
                cnt_bdivs = 0
                # optimize
                opt_cd.step()
                # clear grads
                opt_cd.zero_grad()
                # update progbar
                pbar.set_description('%d | phase 2 | train loss: %.5f' % (n,loss.cpu()))
                pbar.update()
                # test
                if pbar.n % args.snaperiod_2 == 0:
                    with torch.no_grad():
                        x1, x2, x3 = sample_random_batch(test_dset, batch_size=3)
                        x1 = x1.to(gpu)
                        x2 = x2.to(gpu)
                        x3 = (x3).le(0.5).to(torch.uint8) * 255

                        input = torch.cat((x1, x2), dim=1)
                        output = model_cn(input)
                        completed = poisson_blend(output, x1, x3)
                        
                        imgs = torch.cat((x1.cpu(), x2.cpu(), output.cpu(),completed.cpu()), dim=2)
                        imgpath = os.path.join(args.result_dir, 'phase_2', '%d_step%d.png' % (n , pbar.n))
                        model_cd_path = os.path.join(args.result_dir, 'phase_2', '%d_model_cn_step%d' % (n , pbar.n))
                        save_image(imgs, imgpath, nrow=len(x1))
                        if args.data_parallel:
                            torch.save(model_cd.module.state_dict(), model_cd_path)
                        else:
                            torch.save(model_cd.state_dict(), model_cd_path)
                # terminate
                if pbar.n >= steps:
                    break
    pbar.close()

# %%
# train_D(1,11)

# %%
def train_DG(n, steps):
    cnt_bdivs = 0
    pbar = tqdm(total=steps)
    while pbar.n < steps:
        for street_img, mask_poeple, mask, left_top in train_loader:

            # fake forward
            street_img = street_img.to(gpu)
            mask_poeple = mask_poeple.to(gpu)
            mask = mask.to(gpu)

            fake = torch.zeros((len(street_img), 1)).to(gpu)
            input_cn = torch.cat((street_img, mask_poeple), dim=1)
            output_cn = model_cn(input_cn)

            input_gd_fake = output_cn.detach()
            output_fake = model_cd(input_gd_fake.to(gpu))
            loss_cd_fake = bceloss(output_fake, fake)

            # real forward
            real = torch.ones((len(street_img), 1)).to(gpu)
            input_gd_real = street_img
            output_real = model_cd(input_gd_real.to(gpu))
            loss_cd_real = bceloss(output_real, real)

            # reduce
            loss_cd = (loss_cd_fake + loss_cd_real) * alpha / 2.

            # backward model_cd
            loss_cd.backward()


            cnt_bdivs += 1
            if cnt_bdivs >= args.bdivs:
                # optimize
                opt_cd.step()
                # clear grads
                opt_cd.zero_grad()

            # forward model_cn
            #loss_cn_1 = torch.nn.functional.mse_loss(output_cn, street_img)
            loss_cn_1 = completion_network_loss_P(street_img, mask_poeple, mask, output_cn, left_top, height = 128 , width = 64)
            input_gd_fake = output_cn
            output_fake = model_cd(input_gd_fake.to(gpu))
            loss_cn_2 = bceloss(output_fake, real)

            # reduce
            loss_cn = (loss_cn_1 + alpha * loss_cn_2) / 2.

            # backward model_cn
            loss_cn.backward()

            if cnt_bdivs >= args.bdivs:
                cnt_bdivs = 0
                # optimize
                opt_cn.step()
                # clear grads
                opt_cn.zero_grad()
                # update progbar
                pbar.set_description('%d | phase 3 | train loss (cd): %.5f (cn): %.5f' % (n, loss_cd.cpu(), loss_cn.cpu()))
                pbar.update()
                # test
                if pbar.n % args.snaperiod_3 == 0:
                    with torch.no_grad():
                        x1, x2, x3 = sample_random_batch(test_dset, batch_size=3)
                        x1 = x1.to(gpu)
                        x2 = x2.to(gpu)
                        x3 = (x3).le(0.5).to(torch.uint8) * 255
                        
                        torch.where(tense_tensor==0,torch.tensor(-1),tense_tensor)
                        
                        input = torch.cat((x1, x2), dim=1)
                        output = model_cn(input)
                        completed = poisson_blend(output, x1, x3)
                        imgs = torch.cat((x1.cpu(), x2.cpu(), output.cpu(),completed.cpu()), dim=2)

                        imgpath = os.path.join(args.result_dir, 'phase_3', '%d_step%d.png' % (n, pbar.n))

                        model_cn_path = os.path.join(args.result_dir, 'phase_3', '%d_model_cn_step%d' % (n , pbar.n))
                        model_cd_path = os.path.join(args.result_dir, 'phase_3', '%d_model_cd_step%d' % (n , pbar.n))
                        save_image(imgs, imgpath, nrow=len(x1))
                        if args.data_parallel:
                            torch.save(model_cn.module.state_dict(), model_cn_path)
                            torch.save(model_cd.module.state_dict(), model_cd_path)
                        else:
                            torch.save(model_cn.state_dict(), model_cn_path)
                            torch.save(model_cd.state_dict(), model_cd_path)
                # terminate
                if pbar.n >= steps:
                    break
    pbar.close()

# %%
import torchvision.transforms as transforms

x1, x2, x3 = sample_random_batch(test_dset, batch_size=1)
# print(x3[0].shape)
# print(x3[0].view([256,256,3]).numpy().shape)
# print(0 in (x3[0]*255).numpy())
# print((x3[0]*255).numpy().astype('uint8'))
x3 = (x3).le(0.5).to(torch.uint8) * 255
print(type(x3[0][0][0][0]))
print(type((x3*255).le(1).int() * 255))
print((x3*255).le(1).double().shape)
transforms.functional.to_pil_image(x3[0])

Image.fromarray(x3.view([256,256,3]).numpy().astype('uint8'))


# def invert_mask()
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# torch.Size([1, 3, 256, 256])
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F26A4500CC0>

# %%
# train_DG(1,10)

# %%
train_G(1,4000)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
#
# 1 | phase 1 | train loss: 0.00818:   0%|          | 0/4000 [00:00<?, ?it/s]
#
# 1 | phase 1 | train loss: 0.00818:   0%|          | 1/4000 [00:00<32:17,  2.06it/s]
#
# 1 | phase 1 | train loss: 0.00822:   0%|          | 1/4000 [00:00<32:17,  2.06it/s]
#
# 1 | phase 1 | train loss: 0.00822:   0%|          | 2/4000 [00:00<31:36,  2.11it/s]
#
# 1 | phase 1 | train loss: 0.00914:   0%|          | 2/4000 [00:01<31:36,  2.11it/s]
#
# 1 | phase 1 | train loss: 0.00914:   0%|          | 3/4000 [00:01<31:08,  2.14it/s]
#
# 1 | phase 1 | train loss: 0.00886:   0%|          | 3/4000 [00:01<31:08,  2.14it/s]
#
# 1 | phase 1 | train loss: 0.00886:   0%|          | 4/4000 [00:01<30:48,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00765:   0%|          | 4/4000 [00:02<30:48,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00765:   0%|          | 5/4000 [00:02<30:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00875:   0%|          | 5/4000 [00:02<30:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00875:   0%|          | 6/4000 [00:02<30:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00799:   0%|          | 6/4000 [00:03<30:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00799:   0%|          | 7/4000 [00:03<30:18,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00779:   0%|          | 7/4000 [00:03<30:18,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00779:   0%|          | 8/4000 [00:03<30:14,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00857:   0%|          | 8/4000 [00:04<30:14,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00857:   0%|          | 9/4000 [00:04<30:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00806:   0%|          | 9/4000 [00:04<30:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00806:   0%|          | 10/4000 [00:04<30:21,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00849:   0%|          | 10/4000 [00:05<30:21,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00849:   0%|          | 11/4000 [00:05<30:14,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00678:   0%|          | 11/4000 [00:05<30:14,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00678:   0%|          | 12/4000 [00:05<30:12,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00851:   0%|          | 12/4000 [00:05<30:12,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00851:   0%|          | 13/4000 [00:05<30:09,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00722:   0%|          | 13/4000 [00:06<30:09,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00722:   0%|          | 14/4000 [00:06<30:06,  2.21it/s]
#
# 1 | phase 1 | train loss: 0.00867:   0%|          | 14/4000 [00:06<30:06,  2.21it/s]
#
# 1 | phase 1 | train loss: 0.00867:   0%|          | 15/4000 [00:06<30:07,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00868:   0%|          | 15/4000 [00:07<30:07,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00868:   0%|          | 16/4000 [00:07<30:08,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00741:   0%|          | 16/4000 [00:07<30:08,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00741:   0%|          | 17/4000 [00:07<30:08,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00853:   0%|          | 17/4000 [00:08<30:08,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00853:   0%|          | 18/4000 [00:08<30:11,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00818:   0%|          | 18/4000 [00:08<30:11,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00818:   0%|          | 19/4000 [00:08<30:12,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00979:   0%|          | 19/4000 [00:09<30:12,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00979:   0%|          | 20/4000 [00:09<30:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00913:   0%|          | 20/4000 [00:09<30:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00913:   1%|          | 21/4000 [00:09<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01074:   1%|          | 21/4000 [00:10<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01074:   1%|          | 22/4000 [00:10<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00976:   1%|          | 22/4000 [00:10<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00976:   1%|          | 23/4000 [00:10<30:11,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00790:   1%|          | 23/4000 [00:10<30:11,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00790:   1%|          | 24/4000 [00:10<30:10,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00834:   1%|          | 24/4000 [00:11<30:10,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00834:   1%|          | 25/4000 [00:11<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00779:   1%|          | 25/4000 [00:11<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00779:   1%|          | 26/4000 [00:11<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00954:   1%|          | 26/4000 [00:12<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00954:   1%|          | 27/4000 [00:12<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00797:   1%|          | 27/4000 [00:12<30:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00797:   1%|          | 28/4000 [00:12<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00878:   1%|          | 28/4000 [00:13<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00878:   1%|          | 29/4000 [00:13<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00784:   1%|          | 29/4000 [00:13<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00784:   1%|          | 30/4000 [00:13<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00747:   1%|          | 30/4000 [00:14<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00747:   1%|          | 31/4000 [00:14<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   1%|          | 31/4000 [00:14<30:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   1%|          | 32/4000 [00:14<30:19,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00904:   1%|          | 32/4000 [00:15<30:19,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00904:   1%|          | 33/4000 [00:15<30:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   1%|          | 33/4000 [00:15<30:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   1%|          | 34/4000 [00:15<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00738:   1%|          | 34/4000 [00:15<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00738:   1%|          | 35/4000 [00:15<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00876:   1%|          | 35/4000 [00:16<30:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00876:   1%|          | 36/4000 [00:16<30:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00882:   1%|          | 36/4000 [00:16<30:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00882:   1%|          | 37/4000 [00:16<30:32,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00762:   1%|          | 37/4000 [00:17<30:32,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00762:   1%|          | 38/4000 [00:17<30:25,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00735:   1%|          | 38/4000 [00:17<30:25,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00735:   1%|          | 39/4000 [00:17<30:22,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00754:   1%|          | 39/4000 [00:18<30:22,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00754:   1%|          | 40/4000 [00:18<30:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00792:   1%|          | 40/4000 [00:18<30:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00792:   1%|          | 41/4000 [00:18<30:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00784:   1%|          | 41/4000 [00:19<30:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00784:   1%|          | 42/4000 [00:19<30:30,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00789:   1%|          | 42/4000 [00:19<30:30,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00789:   1%|          | 43/4000 [00:19<30:37,  2.15it/s]
#
# 1 | phase 1 | train loss: 0.00931:   1%|          | 43/4000 [00:20<30:37,  2.15it/s]
#
# 1 | phase 1 | train loss: 0.00931:   1%|          | 44/4000 [00:20<30:28,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00917:   1%|          | 44/4000 [00:20<30:28,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00917:   1%|          | 45/4000 [00:20<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00889:   1%|          | 45/4000 [00:21<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00889:   1%|          | 46/4000 [00:21<30:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01030:   1%|          | 46/4000 [00:21<30:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01030:   1%|          | 47/4000 [00:21<30:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00896:   1%|          | 47/4000 [00:21<30:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00896:   1%|          | 48/4000 [00:21<30:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00926:   1%|          | 48/4000 [00:22<30:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00926:   1%|          | 49/4000 [00:22<30:11,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01067:   1%|          | 49/4000 [00:22<30:11,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01067:   1%|▏         | 50/4000 [00:22<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00810:   1%|▏         | 50/4000 [00:23<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00810:   1%|▏         | 51/4000 [00:23<30:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00779:   1%|▏         | 51/4000 [00:23<30:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00779:   1%|▏         | 52/4000 [00:23<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00798:   1%|▏         | 52/4000 [00:24<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00798:   1%|▏         | 53/4000 [00:24<30:17,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00834:   1%|▏         | 53/4000 [00:24<30:17,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00834:   1%|▏         | 54/4000 [00:24<30:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00848:   1%|▏         | 54/4000 [00:25<30:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00848:   1%|▏         | 55/4000 [00:25<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00677:   1%|▏         | 55/4000 [00:25<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00677:   1%|▏         | 56/4000 [00:25<30:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00761:   1%|▏         | 56/4000 [00:26<30:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00761:   1%|▏         | 57/4000 [00:26<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00786:   1%|▏         | 57/4000 [00:26<30:21,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00786:   1%|▏         | 58/4000 [00:26<30:14,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00765:   1%|▏         | 58/4000 [00:26<30:14,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00765:   1%|▏         | 59/4000 [00:27<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00695:   1%|▏         | 59/4000 [00:27<30:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00695:   2%|▏         | 60/4000 [00:27<30:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00736:   2%|▏         | 60/4000 [00:27<30:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00736:   2%|▏         | 61/4000 [00:27<30:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00809:   2%|▏         | 61/4000 [00:28<30:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00809:   2%|▏         | 62/4000 [00:28<30:04,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 62/4000 [00:28<30:04,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 63/4000 [00:28<30:02,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00703:   2%|▏         | 63/4000 [00:29<30:02,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00703:   2%|▏         | 64/4000 [00:29<30:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00839:   2%|▏         | 64/4000 [00:29<30:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00839:   2%|▏         | 65/4000 [00:29<30:00,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00870:   2%|▏         | 65/4000 [00:30<30:00,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00870:   2%|▏         | 66/4000 [00:30<29:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00854:   2%|▏         | 66/4000 [00:30<29:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00854:   2%|▏         | 67/4000 [00:30<29:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00852:   2%|▏         | 67/4000 [00:31<29:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00852:   2%|▏         | 68/4000 [00:31<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00777:   2%|▏         | 68/4000 [00:31<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00777:   2%|▏         | 69/4000 [00:31<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   2%|▏         | 69/4000 [00:32<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   2%|▏         | 70/4000 [00:32<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00769:   2%|▏         | 70/4000 [00:32<29:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00769:   2%|▏         | 71/4000 [00:32<29:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00710:   2%|▏         | 71/4000 [00:32<29:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00710:   2%|▏         | 72/4000 [00:32<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00956:   2%|▏         | 72/4000 [00:33<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00956:   2%|▏         | 73/4000 [00:33<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00909:   2%|▏         | 73/4000 [00:33<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00909:   2%|▏         | 74/4000 [00:33<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00718:   2%|▏         | 74/4000 [00:34<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00718:   2%|▏         | 75/4000 [00:34<29:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00781:   2%|▏         | 75/4000 [00:34<29:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00781:   2%|▏         | 76/4000 [00:34<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00866:   2%|▏         | 76/4000 [00:35<29:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00866:   2%|▏         | 77/4000 [00:35<29:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00927:   2%|▏         | 77/4000 [00:35<29:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00927:   2%|▏         | 78/4000 [00:35<29:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   2%|▏         | 78/4000 [00:36<29:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   2%|▏         | 79/4000 [00:36<29:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00720:   2%|▏         | 79/4000 [00:36<29:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00720:   2%|▏         | 80/4000 [00:36<29:51,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   2%|▏         | 80/4000 [00:37<29:51,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   2%|▏         | 81/4000 [00:37<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   2%|▏         | 81/4000 [00:37<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   2%|▏         | 82/4000 [00:37<29:43,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00776:   2%|▏         | 82/4000 [00:37<29:43,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00776:   2%|▏         | 83/4000 [00:37<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   2%|▏         | 83/4000 [00:38<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   2%|▏         | 84/4000 [00:38<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00658:   2%|▏         | 84/4000 [00:38<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00658:   2%|▏         | 85/4000 [00:38<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   2%|▏         | 85/4000 [00:39<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   2%|▏         | 86/4000 [00:39<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00778:   2%|▏         | 86/4000 [00:39<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00778:   2%|▏         | 87/4000 [00:39<29:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00830:   2%|▏         | 87/4000 [00:40<29:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00830:   2%|▏         | 88/4000 [00:40<29:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00804:   2%|▏         | 88/4000 [00:40<29:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00804:   2%|▏         | 89/4000 [00:40<29:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00893:   2%|▏         | 89/4000 [00:41<29:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00893:   2%|▏         | 90/4000 [00:41<29:49,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00823:   2%|▏         | 90/4000 [00:41<29:49,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00823:   2%|▏         | 91/4000 [00:41<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00822:   2%|▏         | 91/4000 [00:42<29:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00822:   2%|▏         | 92/4000 [00:42<29:49,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01002:   2%|▏         | 92/4000 [00:42<29:49,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01002:   2%|▏         | 93/4000 [00:42<29:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 93/4000 [00:42<29:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 94/4000 [00:43<29:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00815:   2%|▏         | 94/4000 [00:43<29:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00815:   2%|▏         | 95/4000 [00:43<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00846:   2%|▏         | 95/4000 [00:43<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00846:   2%|▏         | 96/4000 [00:43<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00652:   2%|▏         | 96/4000 [00:44<29:46,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00652:   2%|▏         | 97/4000 [00:44<30:01,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00743:   2%|▏         | 97/4000 [00:44<30:01,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00743:   2%|▏         | 98/4000 [00:44<29:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 98/4000 [00:45<29:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00764:   2%|▏         | 99/4000 [00:45<29:52,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00844:   2%|▏         | 99/4000 [00:45<29:52,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00844:   2%|▎         | 100/4000 [00:45<29:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01017:   2%|▎         | 100/4000 [00:46<29:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01017:   3%|▎         | 101/4000 [00:46<29:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00851:   3%|▎         | 101/4000 [00:46<29:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00851:   3%|▎         | 102/4000 [00:46<30:01,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00637:   3%|▎         | 102/4000 [00:47<30:01,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00637:   3%|▎         | 103/4000 [00:47<29:55,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.01149:   3%|▎         | 103/4000 [00:47<29:55,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.01149:   3%|▎         | 104/4000 [00:47<29:51,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00876:   3%|▎         | 104/4000 [00:48<29:51,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00876:   3%|▎         | 105/4000 [00:48<29:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00798:   3%|▎         | 105/4000 [00:48<29:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00798:   3%|▎         | 106/4000 [00:48<29:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00742:   3%|▎         | 106/4000 [00:48<29:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00742:   3%|▎         | 107/4000 [00:48<30:01,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00859:   3%|▎         | 107/4000 [00:49<30:01,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00859:   3%|▎         | 108/4000 [00:49<29:53,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00767:   3%|▎         | 108/4000 [00:49<29:53,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00767:   3%|▎         | 109/4000 [00:49<30:00,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00968:   3%|▎         | 109/4000 [00:50<30:00,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00968:   3%|▎         | 110/4000 [00:50<29:48,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00794:   3%|▎         | 110/4000 [00:50<29:48,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00794:   3%|▎         | 111/4000 [00:50<29:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01120:   3%|▎         | 111/4000 [00:51<29:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01120:   3%|▎         | 112/4000 [00:51<29:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00847:   3%|▎         | 112/4000 [00:51<29:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00847:   3%|▎         | 113/4000 [00:51<29:33,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00673:   3%|▎         | 113/4000 [00:52<29:33,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00673:   3%|▎         | 114/4000 [00:52<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00875:   3%|▎         | 114/4000 [00:52<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00875:   3%|▎         | 115/4000 [00:52<29:28,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.01015:   3%|▎         | 115/4000 [00:53<29:28,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.01015:   3%|▎         | 116/4000 [00:53<29:26,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00933:   3%|▎         | 116/4000 [00:53<29:26,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00933:   3%|▎         | 117/4000 [00:53<29:24,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00763:   3%|▎         | 117/4000 [00:54<29:24,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00763:   3%|▎         | 118/4000 [00:54<29:28,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00727:   3%|▎         | 118/4000 [00:54<29:28,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00727:   3%|▎         | 119/4000 [00:54<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00877:   3%|▎         | 119/4000 [00:54<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00877:   3%|▎         | 120/4000 [00:54<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00889:   3%|▎         | 120/4000 [00:55<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00889:   3%|▎         | 121/4000 [00:55<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00957:   3%|▎         | 121/4000 [00:55<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00957:   3%|▎         | 122/4000 [00:55<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01041:   3%|▎         | 122/4000 [00:56<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01041:   3%|▎         | 123/4000 [00:56<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00977:   3%|▎         | 123/4000 [00:56<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00977:   3%|▎         | 124/4000 [00:56<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00859:   3%|▎         | 124/4000 [00:57<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00859:   3%|▎         | 125/4000 [00:57<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00809:   3%|▎         | 125/4000 [00:57<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00809:   3%|▎         | 126/4000 [00:57<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00860:   3%|▎         | 126/4000 [00:58<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00860:   3%|▎         | 127/4000 [00:58<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00806:   3%|▎         | 127/4000 [00:58<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00806:   3%|▎         | 128/4000 [00:58<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00800:   3%|▎         | 128/4000 [00:59<29:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00800:   3%|▎         | 129/4000 [00:59<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00779:   3%|▎         | 129/4000 [00:59<29:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00779:   3%|▎         | 130/4000 [00:59<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   3%|▎         | 130/4000 [00:59<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   3%|▎         | 131/4000 [00:59<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00840:   3%|▎         | 131/4000 [01:00<29:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00840:   3%|▎         | 132/4000 [01:00<29:28,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   3%|▎         | 132/4000 [01:00<29:28,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   3%|▎         | 133/4000 [01:00<29:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   3%|▎         | 133/4000 [01:01<29:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   3%|▎         | 134/4000 [01:01<29:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00656:   3%|▎         | 134/4000 [01:01<29:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00656:   3%|▎         | 135/4000 [01:01<29:25,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00901:   3%|▎         | 135/4000 [01:02<29:25,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00901:   3%|▎         | 136/4000 [01:02<29:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00919:   3%|▎         | 136/4000 [01:02<29:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00919:   3%|▎         | 137/4000 [01:02<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00754:   3%|▎         | 137/4000 [01:03<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00754:   3%|▎         | 138/4000 [01:03<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00734:   3%|▎         | 138/4000 [01:03<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00734:   3%|▎         | 139/4000 [01:03<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00874:   3%|▎         | 139/4000 [01:04<29:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00874:   4%|▎         | 140/4000 [01:04<29:21,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   4%|▎         | 140/4000 [01:04<29:21,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   4%|▎         | 141/4000 [01:04<29:16,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00901:   4%|▎         | 141/4000 [01:04<29:16,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00901:   4%|▎         | 142/4000 [01:04<29:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00699:   4%|▎         | 142/4000 [01:05<29:13,  2.20it/s]
#
# 1 | phase 1 | train loss: 0.00699:   4%|▎         | 143/4000 [01:05<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▎         | 143/4000 [01:05<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▎         | 144/4000 [01:05<29:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00771:   4%|▎         | 144/4000 [01:06<29:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00771:   4%|▎         | 145/4000 [01:06<29:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00662:   4%|▎         | 145/4000 [01:06<29:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00662:   4%|▎         | 146/4000 [01:06<29:30,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00842:   4%|▎         | 146/4000 [01:07<29:30,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00842:   4%|▎         | 147/4000 [01:07<29:54,  2.15it/s]
#
# 1 | phase 1 | train loss: 0.00756:   4%|▎         | 147/4000 [01:07<29:54,  2.15it/s]
#
# 1 | phase 1 | train loss: 0.00756:   4%|▎         | 148/4000 [01:07<29:43,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00801:   4%|▎         | 148/4000 [01:08<29:43,  2.16it/s]
#
# 1 | phase 1 | train loss: 0.00801:   4%|▎         | 149/4000 [01:08<29:36,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00779:   4%|▎         | 149/4000 [01:08<29:36,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00779:   4%|▍         | 150/4000 [01:08<29:30,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00998:   4%|▍         | 150/4000 [01:09<29:30,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00998:   4%|▍         | 151/4000 [01:09<29:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01013:   4%|▍         | 151/4000 [01:09<29:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.01013:   4%|▍         | 152/4000 [01:09<29:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▍         | 152/4000 [01:10<29:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▍         | 153/4000 [01:10<29:19,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00944:   4%|▍         | 153/4000 [01:10<29:19,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00944:   4%|▍         | 154/4000 [01:10<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00884:   4%|▍         | 154/4000 [01:10<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00884:   4%|▍         | 155/4000 [01:10<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00937:   4%|▍         | 155/4000 [01:11<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00937:   4%|▍         | 156/4000 [01:11<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00907:   4%|▍         | 156/4000 [01:11<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00907:   4%|▍         | 157/4000 [01:11<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00942:   4%|▍         | 157/4000 [01:12<29:17,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00942:   4%|▍         | 158/4000 [01:12<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00819:   4%|▍         | 158/4000 [01:12<29:18,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00819:   4%|▍         | 159/4000 [01:12<29:16,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00803:   4%|▍         | 159/4000 [01:13<29:16,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00803:   4%|▍         | 160/4000 [01:13<29:15,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00694:   4%|▍         | 160/4000 [01:13<29:15,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00694:   4%|▍         | 161/4000 [01:13<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01005:   4%|▍         | 161/4000 [01:14<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01005:   4%|▍         | 162/4000 [01:14<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00897:   4%|▍         | 162/4000 [01:14<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00897:   4%|▍         | 163/4000 [01:14<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01036:   4%|▍         | 163/4000 [01:15<29:14,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01036:   4%|▍         | 164/4000 [01:15<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00853:   4%|▍         | 164/4000 [01:15<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00853:   4%|▍         | 165/4000 [01:15<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▍         | 165/4000 [01:15<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00858:   4%|▍         | 166/4000 [01:15<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00917:   4%|▍         | 166/4000 [01:16<29:12,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00917:   4%|▍         | 167/4000 [01:16<29:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   4%|▍         | 167/4000 [01:16<29:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00765:   4%|▍         | 168/4000 [01:16<29:10,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00718:   4%|▍         | 168/4000 [01:17<29:10,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00718:   4%|▍         | 169/4000 [01:17<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00947:   4%|▍         | 169/4000 [01:17<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00947:   4%|▍         | 170/4000 [01:17<29:08,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00854:   4%|▍         | 170/4000 [01:18<29:08,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00854:   4%|▍         | 171/4000 [01:18<29:08,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00963:   4%|▍         | 171/4000 [01:18<29:08,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00963:   4%|▍         | 172/4000 [01:18<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00832:   4%|▍         | 172/4000 [01:19<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00832:   4%|▍         | 173/4000 [01:19<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00912:   4%|▍         | 173/4000 [01:19<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00912:   4%|▍         | 174/4000 [01:19<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00745:   4%|▍         | 174/4000 [01:20<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00745:   4%|▍         | 175/4000 [01:20<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   4%|▍         | 175/4000 [01:20<29:09,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   4%|▍         | 176/4000 [01:20<29:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00821:   4%|▍         | 176/4000 [01:20<29:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00821:   4%|▍         | 177/4000 [01:20<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00852:   4%|▍         | 177/4000 [01:21<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00852:   4%|▍         | 178/4000 [01:21<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00813:   4%|▍         | 178/4000 [01:21<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00813:   4%|▍         | 179/4000 [01:21<29:07,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00847:   4%|▍         | 179/4000 [01:22<29:07,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00847:   4%|▍         | 180/4000 [01:22<29:06,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00797:   4%|▍         | 180/4000 [01:22<29:06,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00797:   5%|▍         | 181/4000 [01:22<29:06,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00801:   5%|▍         | 181/4000 [01:23<29:06,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00801:   5%|▍         | 182/4000 [01:23<29:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00848:   5%|▍         | 182/4000 [01:23<29:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00848:   5%|▍         | 183/4000 [01:23<29:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00778:   5%|▍         | 183/4000 [01:24<29:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00778:   5%|▍         | 184/4000 [01:24<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00806:   5%|▍         | 184/4000 [01:24<29:05,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00806:   5%|▍         | 185/4000 [01:24<29:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00875:   5%|▍         | 185/4000 [01:25<29:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00875:   5%|▍         | 186/4000 [01:25<29:02,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00716:   5%|▍         | 186/4000 [01:25<29:02,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00716:   5%|▍         | 187/4000 [01:25<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00776:   5%|▍         | 187/4000 [01:26<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00776:   5%|▍         | 188/4000 [01:26<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01114:   5%|▍         | 188/4000 [01:26<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.01114:   5%|▍         | 189/4000 [01:26<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00794:   5%|▍         | 189/4000 [01:26<29:01,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00794:   5%|▍         | 190/4000 [01:26<29:00,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   5%|▍         | 190/4000 [01:27<29:00,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   5%|▍         | 191/4000 [01:27<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00795:   5%|▍         | 191/4000 [01:27<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00795:   5%|▍         | 192/4000 [01:27<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00724:   5%|▍         | 192/4000 [01:28<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00724:   5%|▍         | 193/4000 [01:28<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00736:   5%|▍         | 193/4000 [01:28<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00736:   5%|▍         | 194/4000 [01:28<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00819:   5%|▍         | 194/4000 [01:29<28:59,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00819:   5%|▍         | 195/4000 [01:29<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00807:   5%|▍         | 195/4000 [01:29<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00807:   5%|▍         | 196/4000 [01:29<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00674:   5%|▍         | 196/4000 [01:30<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00674:   5%|▍         | 197/4000 [01:30<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00712:   5%|▍         | 197/4000 [01:30<28:58,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00712:   5%|▍         | 198/4000 [01:30<28:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00711:   5%|▍         | 198/4000 [01:31<28:57,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00711:   5%|▍         | 199/4000 [01:31<28:56,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   5%|▍         | 199/4000 [01:31<28:56,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00760:   5%|▌         | 200/4000 [01:31<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00700:   5%|▌         | 200/4000 [01:31<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00700:   5%|▌         | 201/4000 [01:31<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00745:   5%|▌         | 201/4000 [01:32<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00745:   5%|▌         | 202/4000 [01:32<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00773:   5%|▌         | 202/4000 [01:32<28:55,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00773:   5%|▌         | 203/4000 [01:32<28:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00965:   5%|▌         | 203/4000 [01:33<28:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00965:   5%|▌         | 204/4000 [01:33<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00792:   5%|▌         | 204/4000 [01:33<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00792:   5%|▌         | 205/4000 [01:33<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00774:   5%|▌         | 205/4000 [01:34<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00774:   5%|▌         | 206/4000 [01:34<28:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   5%|▌         | 206/4000 [01:34<28:54,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   5%|▌         | 207/4000 [01:34<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00726:   5%|▌         | 207/4000 [01:35<28:53,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00726:   5%|▌         | 208/4000 [01:35<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00945:   5%|▌         | 208/4000 [01:35<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00945:   5%|▌         | 209/4000 [01:35<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00692:   5%|▌         | 209/4000 [01:36<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00692:   5%|▌         | 210/4000 [01:36<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00763:   5%|▌         | 210/4000 [01:36<28:52,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00763:   5%|▌         | 211/4000 [01:36<28:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00717:   5%|▌         | 211/4000 [01:36<28:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00717:   5%|▌         | 212/4000 [01:36<28:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00772:   5%|▌         | 212/4000 [01:37<28:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00772:   5%|▌         | 213/4000 [01:37<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00728:   5%|▌         | 213/4000 [01:37<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00728:   5%|▌         | 214/4000 [01:37<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00741:   5%|▌         | 214/4000 [01:38<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00741:   5%|▌         | 215/4000 [01:38<28:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00786:   5%|▌         | 215/4000 [01:38<28:50,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00786:   5%|▌         | 216/4000 [01:38<28:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00783:   5%|▌         | 216/4000 [01:39<28:49,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00783:   5%|▌         | 217/4000 [01:39<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00661:   5%|▌         | 217/4000 [01:39<28:48,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00661:   5%|▌         | 218/4000 [01:39<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00825:   5%|▌         | 218/4000 [01:40<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00825:   5%|▌         | 219/4000 [01:40<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00767:   5%|▌         | 219/4000 [01:40<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00767:   6%|▌         | 220/4000 [01:40<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00853:   6%|▌         | 220/4000 [01:41<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00853:   6%|▌         | 221/4000 [01:41<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00691:   6%|▌         | 221/4000 [01:41<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00691:   6%|▌         | 222/4000 [01:41<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   6%|▌         | 222/4000 [01:42<28:47,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00829:   6%|▌         | 223/4000 [01:42<28:59,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00785:   6%|▌         | 223/4000 [01:42<28:59,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00785:   6%|▌         | 224/4000 [01:42<28:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00690:   6%|▌         | 224/4000 [01:42<28:56,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00690:   6%|▌         | 225/4000 [01:42<28:53,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00694:   6%|▌         | 225/4000 [01:43<28:53,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00694:   6%|▌         | 226/4000 [01:43<28:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00656:   6%|▌         | 226/4000 [01:43<28:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00656:   6%|▌         | 227/4000 [01:43<28:51,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00824:   6%|▌         | 227/4000 [01:44<28:51,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00824:   6%|▌         | 228/4000 [01:44<28:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00849:   6%|▌         | 228/4000 [01:44<28:50,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00849:   6%|▌         | 229/4000 [01:44<28:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00827:   6%|▌         | 229/4000 [01:45<28:48,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00827:   6%|▌         | 230/4000 [01:45<28:46,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00814:   6%|▌         | 230/4000 [01:45<28:46,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00814:   6%|▌         | 231/4000 [01:45<28:45,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00750:   6%|▌         | 231/4000 [01:46<28:45,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00750:   6%|▌         | 232/4000 [01:46<28:44,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00864:   6%|▌         | 232/4000 [01:46<28:44,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00864:   6%|▌         | 233/4000 [01:46<28:42,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00803:   6%|▌         | 233/4000 [01:47<28:42,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00803:   6%|▌         | 234/4000 [01:47<28:47,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00812:   6%|▌         | 234/4000 [01:47<28:47,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00812:   6%|▌         | 235/4000 [01:47<28:44,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00704:   6%|▌         | 235/4000 [01:47<28:44,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00704:   6%|▌         | 236/4000 [01:47<28:42,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00797:   6%|▌         | 236/4000 [01:48<28:42,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00797:   6%|▌         | 237/4000 [01:48<28:44,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00666:   6%|▌         | 237/4000 [01:48<28:44,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00666:   6%|▌         | 238/4000 [01:48<28:42,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00713:   6%|▌         | 238/4000 [01:49<28:42,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00713:   6%|▌         | 239/4000 [01:49<28:40,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00827:   6%|▌         | 239/4000 [01:49<28:40,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00827:   6%|▌         | 240/4000 [01:49<28:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00765:   6%|▌         | 240/4000 [01:50<28:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00765:   6%|▌         | 241/4000 [01:50<28:39,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00676:   6%|▌         | 241/4000 [01:50<28:39,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00676:   6%|▌         | 242/4000 [01:50<28:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00728:   6%|▌         | 242/4000 [01:51<28:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00728:   6%|▌         | 243/4000 [01:51<28:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00701:   6%|▌         | 243/4000 [01:51<28:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00701:   6%|▌         | 244/4000 [01:51<28:38,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00739:   6%|▌         | 244/4000 [01:52<28:38,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00739:   6%|▌         | 245/4000 [01:52<28:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00732:   6%|▌         | 245/4000 [01:52<28:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00732:   6%|▌         | 246/4000 [01:52<28:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00670:   6%|▌         | 246/4000 [01:53<28:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00670:   6%|▌         | 247/4000 [01:53<28:36,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00649:   6%|▌         | 247/4000 [01:53<28:36,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00649:   6%|▌         | 248/4000 [01:53<28:35,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   6%|▌         | 248/4000 [01:53<28:35,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   6%|▌         | 249/4000 [01:53<28:35,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00824:   6%|▌         | 249/4000 [01:54<28:35,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00824:   6%|▋         | 250/4000 [01:54<28:36,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00742:   6%|▋         | 250/4000 [01:54<28:36,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00742:   6%|▋         | 251/4000 [01:54<28:33,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00821:   6%|▋         | 251/4000 [01:55<28:33,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00821:   6%|▋         | 252/4000 [01:55<28:32,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00610:   6%|▋         | 252/4000 [01:55<28:32,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00610:   6%|▋         | 253/4000 [01:55<28:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00707:   6%|▋         | 253/4000 [01:56<28:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00707:   6%|▋         | 254/4000 [01:56<28:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00817:   6%|▋         | 254/4000 [01:56<28:31,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00817:   6%|▋         | 255/4000 [01:56<28:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00750:   6%|▋         | 255/4000 [01:57<28:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00750:   6%|▋         | 256/4000 [01:57<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00763:   6%|▋         | 256/4000 [01:57<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00763:   6%|▋         | 257/4000 [01:57<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00671:   6%|▋         | 257/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00671:   6%|▋         | 258/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   6%|▋         | 258/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   6%|▋         | 259/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00692:   6%|▋         | 259/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00692:   6%|▋         | 260/4000 [01:58<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00755:   6%|▋         | 260/4000 [01:59<28:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00755:   7%|▋         | 261/4000 [01:59<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00912:   7%|▋         | 261/4000 [01:59<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00912:   7%|▋         | 262/4000 [01:59<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00947:   7%|▋         | 262/4000 [02:00<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00947:   7%|▋         | 263/4000 [02:00<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00770:   7%|▋         | 263/4000 [02:00<28:27,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00770:   7%|▋         | 264/4000 [02:00<28:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00827:   7%|▋         | 264/4000 [02:01<28:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00827:   7%|▋         | 265/4000 [02:01<28:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00842:   7%|▋         | 265/4000 [02:01<28:26,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00842:   7%|▋         | 266/4000 [02:01<28:25,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00824:   7%|▋         | 266/4000 [02:02<28:25,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00824:   7%|▋         | 267/4000 [02:02<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00742:   7%|▋         | 267/4000 [02:02<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00742:   7%|▋         | 268/4000 [02:02<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00825:   7%|▋         | 268/4000 [02:03<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00825:   7%|▋         | 269/4000 [02:03<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   7%|▋         | 269/4000 [02:03<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00731:   7%|▋         | 270/4000 [02:03<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00796:   7%|▋         | 270/4000 [02:03<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00796:   7%|▋         | 271/4000 [02:03<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   7%|▋         | 271/4000 [02:04<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00872:   7%|▋         | 272/4000 [02:04<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00832:   7%|▋         | 272/4000 [02:04<28:24,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00832:   7%|▋         | 273/4000 [02:04<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00883:   7%|▋         | 273/4000 [02:05<28:23,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00883:   7%|▋         | 274/4000 [02:05<28:22,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00681:   7%|▋         | 274/4000 [02:05<28:22,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00681:   7%|▋         | 275/4000 [02:05<28:22,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   7%|▋         | 275/4000 [02:06<28:22,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00805:   7%|▋         | 276/4000 [02:06<28:22,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00766:   7%|▋         | 276/4000 [02:06<28:22,  2.19it/s]
#
# ...
#
# 1 | phase 1 | train loss: 0.00471:  98%|█████████▊| 3910/4000 [30:01<00:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00429:  98%|█████████▊| 3910/4000 [30:02<00:41,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00429:  98%|█████████▊| 3911/4000 [30:02<00:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00377:  98%|█████████▊| 3911/4000 [30:02<00:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00377:  98%|█████████▊| 3912/4000 [30:02<00:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00484:  98%|█████████▊| 3912/4000 [30:02<00:40,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00484:  98%|█████████▊| 3913/4000 [30:02<00:39,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00500:  98%|█████████▊| 3913/4000 [30:03<00:39,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00500:  98%|█████████▊| 3914/4000 [30:03<00:39,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00364:  98%|█████████▊| 3914/4000 [30:03<00:39,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00364:  98%|█████████▊| 3915/4000 [30:03<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00465:  98%|█████████▊| 3915/4000 [30:04<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00465:  98%|█████████▊| 3916/4000 [30:04<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00382:  98%|█████████▊| 3916/4000 [30:04<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00382:  98%|█████████▊| 3917/4000 [30:04<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00407:  98%|█████████▊| 3917/4000 [30:05<00:38,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00407:  98%|█████████▊| 3918/4000 [30:05<00:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00437:  98%|█████████▊| 3918/4000 [30:05<00:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00437:  98%|█████████▊| 3919/4000 [30:05<00:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00364:  98%|█████████▊| 3919/4000 [30:06<00:37,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00364:  98%|█████████▊| 3920/4000 [30:06<00:36,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00361:  98%|█████████▊| 3920/4000 [30:06<00:36,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00361:  98%|█████████▊| 3921/4000 [30:06<00:36,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00689:  98%|█████████▊| 3921/4000 [30:07<00:36,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00689:  98%|█████████▊| 3922/4000 [30:07<00:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00439:  98%|█████████▊| 3922/4000 [30:07<00:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00439:  98%|█████████▊| 3923/4000 [30:07<00:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00460:  98%|█████████▊| 3923/4000 [30:07<00:35,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00460:  98%|█████████▊| 3924/4000 [30:07<00:34,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00410:  98%|█████████▊| 3924/4000 [30:08<00:34,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00410:  98%|█████████▊| 3925/4000 [30:08<00:34,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00422:  98%|█████████▊| 3925/4000 [30:08<00:34,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00422:  98%|█████████▊| 3926/4000 [30:08<00:33,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00433:  98%|█████████▊| 3926/4000 [30:09<00:33,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00433:  98%|█████████▊| 3927/4000 [30:09<00:33,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  98%|█████████▊| 3927/4000 [30:09<00:33,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  98%|█████████▊| 3928/4000 [30:09<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00412:  98%|█████████▊| 3928/4000 [30:10<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00412:  98%|█████████▊| 3929/4000 [30:10<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00468:  98%|█████████▊| 3929/4000 [30:10<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00468:  98%|█████████▊| 3930/4000 [30:10<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00470:  98%|█████████▊| 3930/4000 [30:11<00:32,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00470:  98%|█████████▊| 3931/4000 [30:11<00:31,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00363:  98%|█████████▊| 3931/4000 [30:11<00:31,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00363:  98%|█████████▊| 3932/4000 [30:11<00:31,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427:  98%|█████████▊| 3932/4000 [30:12<00:31,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427:  98%|█████████▊| 3933/4000 [30:12<00:30,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00392:  98%|█████████▊| 3933/4000 [30:12<00:30,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00392:  98%|█████████▊| 3934/4000 [30:12<00:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00452:  98%|█████████▊| 3934/4000 [30:13<00:30,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00452:  98%|█████████▊| 3935/4000 [30:13<00:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00446:  98%|█████████▊| 3935/4000 [30:13<00:29,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00446:  98%|█████████▊| 3936/4000 [30:13<00:29,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00420:  98%|█████████▊| 3936/4000 [30:13<00:29,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00420:  98%|█████████▊| 3937/4000 [30:13<00:28,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00381:  98%|█████████▊| 3937/4000 [30:14<00:28,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00381:  98%|█████████▊| 3938/4000 [30:14<00:28,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00414:  98%|█████████▊| 3938/4000 [30:14<00:28,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00414:  98%|█████████▊| 3939/4000 [30:14<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00444:  98%|█████████▊| 3939/4000 [30:15<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00444:  98%|█████████▊| 3940/4000 [30:15<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00456:  98%|█████████▊| 3940/4000 [30:15<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00456:  99%|█████████▊| 3941/4000 [30:15<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00411:  99%|█████████▊| 3941/4000 [30:16<00:27,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00411:  99%|█████████▊| 3942/4000 [30:16<00:26,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00487:  99%|█████████▊| 3942/4000 [30:16<00:26,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00487:  99%|█████████▊| 3943/4000 [30:16<00:26,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00576:  99%|█████████▊| 3943/4000 [30:17<00:26,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00576:  99%|█████████▊| 3944/4000 [30:17<00:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00416:  99%|█████████▊| 3944/4000 [30:17<00:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00416:  99%|█████████▊| 3945/4000 [30:17<00:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  99%|█████████▊| 3945/4000 [30:18<00:25,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  99%|█████████▊| 3946/4000 [30:18<00:24,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00501:  99%|█████████▊| 3946/4000 [30:18<00:24,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00501:  99%|█████████▊| 3947/4000 [30:18<00:24,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00594:  99%|█████████▊| 3947/4000 [30:18<00:24,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00594:  99%|█████████▊| 3948/4000 [30:18<00:23,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00440:  99%|█████████▊| 3948/4000 [30:19<00:23,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00440:  99%|█████████▊| 3949/4000 [30:19<00:23,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00492:  99%|█████████▊| 3949/4000 [30:19<00:23,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00492:  99%|█████████▉| 3950/4000 [30:19<00:23,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00444:  99%|█████████▉| 3950/4000 [30:20<00:23,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00444:  99%|█████████▉| 3951/4000 [30:20<00:22,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00496:  99%|█████████▉| 3951/4000 [30:20<00:22,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00496:  99%|█████████▉| 3952/4000 [30:20<00:22,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00460:  99%|█████████▉| 3952/4000 [30:21<00:22,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00460:  99%|█████████▉| 3953/4000 [30:21<00:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00412:  99%|█████████▉| 3953/4000 [30:21<00:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00412:  99%|█████████▉| 3954/4000 [30:21<00:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00433:  99%|█████████▉| 3954/4000 [30:22<00:21,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00433:  99%|█████████▉| 3955/4000 [30:22<00:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00438:  99%|█████████▉| 3955/4000 [30:22<00:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00438:  99%|█████████▉| 3956/4000 [30:22<00:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00411:  99%|█████████▉| 3956/4000 [30:23<00:20,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00411:  99%|█████████▉| 3957/4000 [30:23<00:19,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00320:  99%|█████████▉| 3957/4000 [30:23<00:19,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00320:  99%|█████████▉| 3958/4000 [30:23<00:19,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00459:  99%|█████████▉| 3958/4000 [30:24<00:19,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00459:  99%|█████████▉| 3959/4000 [30:24<00:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00552:  99%|█████████▉| 3959/4000 [30:24<00:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00552:  99%|█████████▉| 3960/4000 [30:24<00:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00463:  99%|█████████▉| 3960/4000 [30:24<00:18,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00463:  99%|█████████▉| 3961/4000 [30:24<00:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00467:  99%|█████████▉| 3961/4000 [30:25<00:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00467:  99%|█████████▉| 3962/4000 [30:25<00:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  99%|█████████▉| 3962/4000 [30:25<00:17,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00436:  99%|█████████▉| 3963/4000 [30:25<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00406:  99%|█████████▉| 3963/4000 [30:26<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00406:  99%|█████████▉| 3964/4000 [30:26<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00435:  99%|█████████▉| 3964/4000 [30:26<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00435:  99%|█████████▉| 3965/4000 [30:26<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00377:  99%|█████████▉| 3965/4000 [30:27<00:16,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00377:  99%|█████████▉| 3966/4000 [30:27<00:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00448:  99%|█████████▉| 3966/4000 [30:27<00:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00448:  99%|█████████▉| 3967/4000 [30:27<00:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00392:  99%|█████████▉| 3967/4000 [30:28<00:15,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00392:  99%|█████████▉| 3968/4000 [30:28<00:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00457:  99%|█████████▉| 3968/4000 [30:28<00:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00457:  99%|█████████▉| 3969/4000 [30:28<00:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00406:  99%|█████████▉| 3969/4000 [30:29<00:14,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00406:  99%|█████████▉| 3970/4000 [30:29<00:13,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00661:  99%|█████████▉| 3970/4000 [30:29<00:13,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00661:  99%|█████████▉| 3971/4000 [30:29<00:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00496:  99%|█████████▉| 3971/4000 [30:29<00:13,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00496:  99%|█████████▉| 3972/4000 [30:29<00:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00646:  99%|█████████▉| 3972/4000 [30:30<00:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00646:  99%|█████████▉| 3973/4000 [30:30<00:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00372:  99%|█████████▉| 3973/4000 [30:30<00:12,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00372:  99%|█████████▉| 3974/4000 [30:30<00:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00546:  99%|█████████▉| 3974/4000 [30:31<00:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00546:  99%|█████████▉| 3975/4000 [30:31<00:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00630:  99%|█████████▉| 3975/4000 [30:31<00:11,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00630:  99%|█████████▉| 3976/4000 [30:31<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00515:  99%|█████████▉| 3976/4000 [30:32<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00515:  99%|█████████▉| 3977/4000 [30:32<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00468:  99%|█████████▉| 3977/4000 [30:32<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00468:  99%|█████████▉| 3978/4000 [30:32<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00466:  99%|█████████▉| 3978/4000 [30:33<00:10,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00466:  99%|█████████▉| 3979/4000 [30:33<00:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00452:  99%|█████████▉| 3979/4000 [30:33<00:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00452: 100%|█████████▉| 3980/4000 [30:33<00:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00438: 100%|█████████▉| 3980/4000 [30:34<00:09,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00438: 100%|█████████▉| 3981/4000 [30:34<00:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00500: 100%|█████████▉| 3981/4000 [30:34<00:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00500: 100%|█████████▉| 3982/4000 [30:34<00:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00461: 100%|█████████▉| 3982/4000 [30:34<00:08,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00461: 100%|█████████▉| 3983/4000 [30:34<00:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00486: 100%|█████████▉| 3983/4000 [30:35<00:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00486: 100%|█████████▉| 3984/4000 [30:35<00:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00423: 100%|█████████▉| 3984/4000 [30:35<00:07,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00423: 100%|█████████▉| 3985/4000 [30:35<00:06,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00479: 100%|█████████▉| 3985/4000 [30:36<00:06,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00479: 100%|█████████▉| 3986/4000 [30:36<00:06,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00524: 100%|█████████▉| 3986/4000 [30:36<00:06,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00524: 100%|█████████▉| 3987/4000 [30:36<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427: 100%|█████████▉| 3987/4000 [30:37<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427: 100%|█████████▉| 3988/4000 [30:37<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00387: 100%|█████████▉| 3988/4000 [30:37<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00387: 100%|█████████▉| 3989/4000 [30:37<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00504: 100%|█████████▉| 3989/4000 [30:38<00:05,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00504: 100%|█████████▉| 3990/4000 [30:38<00:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00556: 100%|█████████▉| 3990/4000 [30:38<00:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00556: 100%|█████████▉| 3991/4000 [30:38<00:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00505: 100%|█████████▉| 3991/4000 [30:39<00:04,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00505: 100%|█████████▉| 3992/4000 [30:39<00:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00386: 100%|█████████▉| 3992/4000 [30:39<00:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00386: 100%|█████████▉| 3993/4000 [30:39<00:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00527: 100%|█████████▉| 3993/4000 [30:40<00:03,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00527: 100%|█████████▉| 3994/4000 [30:40<00:02,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00416: 100%|█████████▉| 3994/4000 [30:40<00:02,  2.19it/s]
#
# 1 | phase 1 | train loss: 0.00416: 100%|█████████▉| 3995/4000 [30:40<00:02,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00476: 100%|█████████▉| 3995/4000 [30:40<00:02,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00476: 100%|█████████▉| 3996/4000 [30:40<00:01,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00495: 100%|█████████▉| 3996/4000 [30:41<00:01,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00495: 100%|█████████▉| 3997/4000 [30:41<00:01,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00435: 100%|█████████▉| 3997/4000 [30:41<00:01,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00435: 100%|█████████▉| 3998/4000 [30:41<00:00,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00524: 100%|█████████▉| 3998/4000 [30:42<00:00,  2.17it/s]
#
# 1 | phase 1 | train loss: 0.00524: 100%|█████████▉| 3999/4000 [30:42<00:00,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427: 100%|█████████▉| 3999/4000 [30:42<00:00,  2.18it/s]
#
# 1 | phase 1 | train loss: 0.00427: 100%|██████████| 4000/4000 [30:44<00:00,  2.17it/s]

# %%
train_D(1,800)

# %%
train_DG(1,4000)

# %%
# part2

# %%
#train_G(2,500)

# %%
#train_D(2,200)

# %%
#train_DG(2,800)

# %%
Image.open("/root/notebooks/final/gandata/result/phase_3/1_step2000.png")
