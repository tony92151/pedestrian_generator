# %%
import cv2
import numpy as np
from PIL import Image
from detectron_pro import mask_img,mask_img_composite

# %%
def cv2_imshow(img):
    img = img[:,:,[2,1,0]]
    img = Image.fromarray(img)
    display(img)

# %%
im = cv2.imread("/root/notebooks/final/gandata/gandata1/people/000077.jpg")

Image.fromarray(im[:,:,[2,1,0]])
# Out:
# <PIL.Image.Image image mode=RGB size=64x128 at 0x7F046DADA358>

# %%
mask = mask_img("/root/notebooks/final/gandata/gandata1/people/000077.jpg")

# %%
Image.fromarray(mask)
# Out:
# <PIL.Image.Image image mode=1 size=64x128 at 0x7F047309E320>

# %%
result = mask_img_composite("/root/notebooks/final/gandata/gandata1/people/000077.jpg",(64,128))

# %%
Image.fromarray(result[:,:,[2,1,0]])
# Out:
# <PIL.Image.Image image mode=RGB size=64x128 at 0x7F047309EC88>
