baseline_x_APl = [0, 0.0, 1.7633191890617632, 1.782178217821782, 3.4396436074407877, 2.9190867373744487, 4.113893004684306, 7.707224116972154, 5.752116554669624, 10.769885647887474, 9.641018215747003, 15.397469320973952, 16.42316806685397, 16.51566185988879, 17.683229298251877, 20.261363501453637, 19.687339417297608, 19.861596278715147, 20.094123223608126, 19.970543070123988, 19.521140753335967, 19.019787414098925, 19.944049421485584, 19.810463748655565, 19.79526734335076]
baseline_y = [5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000, 105000, 110000, 115000, 120000, 126000]

# %%
transfer_x_AP = [3.0228896654525625, 5.324153672946869, 5.883921125721576, 7.498841146150956, 9.511271623711961, 10.098502961924897, 10.651938517694015, 10.512437147892891, 13.551946929841902, 13.560070159877636, 15.566629971613805, 15.774787192580012, 18.103501028521524, 18.507908836041448, 18.606010917413727, 18.889177542853027, 18.889781995680586, 18.929545461319357, 18.91732702457656, 18.9339833705924]
transfer_x_APs = [1.741281294415763, 2.702557069579737, 3.3751780819810806, 4.015109565144007, 5.735081917857228, 6.087071336304615, 6.3102875457135985, 7.213730765001965, 9.450606864894578, 8.99690356725498, 10.374319470394493, 11.271325528947095, 13.143792203245658, 13.63008906329275, 13.765369763922813, 13.819029101995767, 14.141578261443518, 14.105054802591303, 14.111103662725155, 14.03292682263308]
transfer_x_APm = [4.878469814304964, 8.785605927935105, 9.024068379213155, 11.420462194837807, 13.743268393342664, 14.67094392977128, 15.465358716295906, 14.22624427797666, 17.577967363400894, 18.561235365029315, 20.854398016454727, 20.766760487150144, 23.363583179906854, 23.487446613896, 23.50763469266154, 24.191088100589077, 23.87906043114375, 23.99819041135033, 24.088281683981325, 24.11692733386727]
transfer_x_APl = [1.3696369636963694, 4.405035051673831, 8.462490110708352, 12.774737673366518, 14.466704102965034, 19.149713559855318, 20.46804058396883, 14.013323707865405, 24.019100370938755, 23.34162753433941, 27.59444325088977, 24.88093318348229, 30.630966122562995, 28.878999187439774, 30.08023234228046, 30.398275097729627, 30.928071664150398, 31.07396707021995, 31.028690435093313, 31.04409102386782]
transfer_y = [35000, 40000, 45000, 50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000, 100000, 105000, 110000, 115000, 120000, 125000, 126000]

# %%
import matplotlib.pyplot as plt

plt.plot(baseline_y, baseline_x_AP, label = 'baseline AP')
plt.plot(pure_y, pure_x_AP, label = 'Only gandata AP')
plt.plot(transfer_y, transfer_x_AP, label = 'Traing w both')
plt.legend()
plt.title('AP Comparison')
plt.savefig('AP_Comparison.jpg')

# %%
import matplotlib.pyplot as plt
plt.plot(baseline_y, baseline_x_APs, label = 'baseline APs')
plt.plot(pure_y, pure_x_APs, label = 'Only gandata APs')
plt.plot(transfer_y, transfer_x_APs, label = 'Traing w both')
plt.legend()
plt.title('APs Comparison')
plt.savefig('APs_Comparison.jpg')

# %%
plt.plot(baseline_y, baseline_x_APm, label = 'baseline APm')
plt.plot(pure_y, pure_x_APm, label = 'Only gandata APm')
plt.plot(transfer_y, transfer_x_APm, label = 'Traing w both')
plt.legend()
plt.title('APm Comparison')
plt.savefig('APm_Comparison.jpg')

# %%
plt.plot(baseline_y, baseline_x_APl, label = 'baseline APl')
plt.plot(pure_y, pure_x_APl, label = 'Only gandata APl')
plt.plot(transfer_y, transfer_x_APl, label = 'Traing w both')
plt.legend()
plt.title('APl Comparison')
plt.savefig('APl_Comparison.jpg')

# %%
# record the MR in FP == 10^-1
MR_of_baseline = 0.8187003783164779
MR_of_both = 0.7232460461486738
print((MR_of_baseline-MR_of_both)/MR_of_baseline)
# Out:
# 0.11659251014893891
